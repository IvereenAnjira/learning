# %% [markdown]
# Connected to .venv (Python 3.12.4)

# %%
import os 
from dotenv import load_dotenv
load_dotenv()
API_KEY = os.getenv('API_KEY_cypto')

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
url ='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': API_KEY,
}

# %%
session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

import pandas as pd
pd.set_option('display.max_columns',None)

df= pd.json_normalize(data['data'])
# Out:
# {'status': {'timestamp': '2024-10-30T16:28:54.988Z', 'error_code': 0, 'error_message': None, 'elapsed': 15, 'credit_count': 1, 'notice': None, 'total_count': 9904}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11793, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19775315, 'total_supply': 19775315, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T16:26:00.000Z', 'quote': {'USD': {'price': 71916.6929448978, 'volume_24h': 48665146357.37893, 'volume_change_24h': -8.9953, 'percent_change_1h': 0.22471718, 'percent_change_24h': -0.96004906, 'percent_change_7d': 9.19689082, 'percent_change_30d': 13.00245398, 'percent_change_60d': 21.96908778, 'percent_change_90d': 14.00158198, 'market_cap': 1422175256743.6318, 'market_cap_dominance': 58.7187, 'fully_diluted_market_cap': 1510250551842.85, 'tvl': None, 'last_updated': '2024-10-30T16:26:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9468, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120406284.16331623, 'total_supply': 120406284.16331623, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T16:26:00.000Z', 'quote': {'USD': {'price': 2681.318136542628, 'volume_24h': 23915326987.64884, 'volume_change_24h': 8.4159, 'percent_change_1h': 0.15913126, 'percent_change_24h': 1.20664369, 'percent_change_7d': 6.32701258, 'percent_change_30d': 2.81519492, 'percent_change_60d': 6.59969476, 'percent_change_90d': -13.84265569, 'market_cap': 322847553480.80524, 'market_cap_dominance': 13.3394, 'fully_diluted_market_cap': 322847553480.81, 'tvl': None, 'last_updated': '2024-10-30T16:26:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 101997, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 120504138281.46748, 'total_supply': 122337925861.4382, 'platform': {'id': 102 ...

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11793
# 1    1027      Ethereum    ETH      ethereum              9468
# 2     825   Tether USDt   USDT        tether            101997
# 3    1839           BNB    BNB           bnb              2273
# 4    5426        Solana    SOL        solana               776
# 5    3408          USDC   USDC      usd-coin             22753
# 6      52           XRP    XRP           xrp              1413
# 7      74      Dogecoin   DOGE      dogecoin              1090
# 8    1958          TRON    TRX          tron              1059
# 9   11419       Toncoin    TON       toncoin               589
# 10   2010       Cardano    ADA       cardano              1309
# 11   5994     Shiba Inu   SHIB     shiba-inu               895
# 12   5805     Avalanche   AVAX     avalanche               796
# 13   1975     Chainlink   LINK     chainlink              1870
# 14   1831  Bitcoin Cash    BCH  bitcoin-cash               939
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2021-08-26T13:40:22.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2020-08-01T00:00:00.000Z
# 12  2020-07-13T00:00:00.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 9   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 10  [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 11      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 12  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 13  [platform, defi, oracles, smart-contracts, sub...           NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.977532e+07  1.977532e+07            False       NaN         1
# 1         1.204063e+08  1.204063e+08             True       NaN         2
# 2         1.205041e+11  1.223379e+11             True       NaN         3
# 3         1.459309e+08  1.459309e+08            False       NaN         4
# 4         4.703800e+08  5.875381e+08             True       NaN         5
# 5         3.479141e+10  3.479141e+10            False       NaN         6
# 6         5.681186e+10  9.998707e+10            False       NaN         7
# 7         1.465843e+11  1.465842e+11             True       NaN         8
# 8         8.646885e+10  8.646889e+10             True       NaN         9
# 9         2.543854e+09  5.114169e+09             True       NaN        10
# 10        3.498689e+10  4.499521e+10            False       NaN        11
# 11        5.892670e+14  5.895183e+14            False       NaN        12
# 12        4.070832e+08  4.470863e+08            False       NaN        13
# 13        6.268500e+08  1.000000e+09            False       NaN        14
# 14        1.978141e+07  1.978141e+07            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                       7.165966e+10              1.209739e+10      None
# 9                       3.414167e+09              1.703520e+10      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-10-30T16:26:00.000Z     71916.692945          4.866515e+10
# 1   2024-10-30T16:26:00.000Z      2681.318137          2.391533e+10
# 2   2024-10-30T16:26:00.000Z         0.999639          7.949573e+10
# 3   2024-10-30T16:26:00.000Z       596.989812          1.809591e+09
# 4   2024-10-30T16:26:00.000Z       174.114214          3.269233e+09
# 5   2024-10-30T16:26:00.000Z         0.999848          8.642715e+09
# 6   2024-10-30T16:26:00.000Z         0.522371          1.004481e+09
# 7   2024-10-30T16:26:00.000Z         0.165771          3.110709e+09
# 8   2024-10-30T16:26:00.000Z         0.168817          3.983080e+08
# 9   2024-10-30T16:26:00.000Z         4.989562          2.282994e+08
# 10  2024-10-30T16:26:00.000Z         0.355129          3.258804e+08
# 11  2024-10-30T16:26:00.000Z         0.000018          6.569234e+08
# 12  2024-10-30T16:26:00.000Z        26.123346          2.896318e+08
# 13  2024-10-30T16:26:00.000Z        12.168769          3.250658e+08
# 14  2024-10-30T16:26:00.000Z       371.090419          3.903994e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       -8.9953                     0.224717
# 1                        8.4159                     0.159131
# 2                       -4.5054                    -0.005723
# 3                       -0.6112                     0.177929
# 4                      -15.8355                     0.390381
# 5                       -5.4801                    -0.000866
# 6                       -1.7212                     0.179757
# 7                      -20.7336                     0.192282
# 8                        4.0237                     0.194222
# 9                       24.8652                     0.134739
# 10                      12.5342                     0.575576
# 11                      -1.2143                     0.306626
# 12                       6.1901                     0.227013
# 13                      26.2226                    -0.123607
# 14                     -10.3720                     0.212729
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -0.960049                     9.196891
# 1                       1.206644                     6.327013
# 2                      -0.037902                     0.070895
# 3                      -2.058567                     3.376793
# 4                      -4.043190                     4.454753
# 5                      -0.035374                     0.007505
# 6                      -0.855964                     0.098876
# 7                      -6.786945                    20.794220
# 8                       2.121589                     5.651359
# 9                      -1.535405                    -2.273535
# 10                      1.079086                     2.115262
# 11                     -5.115237                     5.178897
# 12                     -2.826325                    -0.933943
# 13                      4.686352                     8.236450
# 14                     -3.974332                     7.503120
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      13.002454                     21.969088
# 1                       2.815195                      6.599695
# 2                      -0.032936                     -0.033059
# 3                       4.171953                     11.786960
# 4                      12.402546                     27.663478
# 5                      -0.010786                     -0.008663
# 6                     -15.801792                     -7.509587
# 7                      40.901013                     63.556871
# 8                       8.071610                      7.417761
# 9                     -14.054187                     -7.286960
# 10                     -6.835083                      1.806102
# 11                      2.981088                     32.713442
# 12                     -7.310993                     13.849098
# 13                      1.516705                      9.752743
# 14                      8.439605                     15.269289
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      14.001582          1.422175e+12
# 1                     -13.842656          3.228476e+11
# 2                       0.033060          1.204606e+11
# 3                       7.185634          8.711928e+10
# 4                       7.696853          8.189984e+10
# 5                      -0.010098          3.478611e+10
# 6                     -10.846896          2.967687e+10
# 7                      43.981527          2.429939e+10
# 8                      32.827891          1.459744e+10
# 9                     -25.997620          1.269272e+10
# 10                     -5.599892          1.242487e+10
# 11                     20.727079          1.082116e+10
# 12                      6.738344          1.063438e+10
# 13                     -2.037577          7.627992e+09
# 14                     -7.697012          7.340690e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          58.7187                        1.510251e+12
# 1                          13.3394                        3.228476e+11
# 2                           4.9772                        1.222938e+11
# 3                           3.5996                        8.711928e+10
# 4                           3.3826                        1.022987e+11
# 5                           1.4367                        3.478611e+10
# 6                           1.2257                        5.223710e+10
# 7                           1.0033                        2.429939e+10
# 8                           0.6029                        1.459744e+10
# 9                           0.5242                        2.551746e+10
# 10                          0.5132                        1.598082e+10
# 11                          0.4471                        1.082577e+10
# 12                          0.4391                        1.869775e+10
# 13                          0.3149                        1.216877e+10
# 14                          0.3031                        7.792899e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 1           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 2           None  2024-10-30T16:26:00.000Z       1027.0      Ethereum
# 3           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 4           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 5           None  2024-10-30T16:26:00.000Z       1027.0      Ethereum
# 6           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 7           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 8           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 9           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 10          None  2024-10-30T16:26:00.000Z          NaN           NaN
# 11          None  2024-10-30T16:26:00.000Z       1027.0      Ethereum
# 12          None  2024-10-30T16:26:00.000Z          NaN           NaN
# 13          None  2024-10-30T16:26:00.000Z       1027.0      Ethereum
# 14          None  2024-10-30T16:26:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 12             NaN           NaN                                         NaN
# 13             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14             NaN           NaN                                         NaN

# %%
df['time_stamp']= pd.to_datetime('now')

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11793
# 1    1027      Ethereum    ETH      ethereum              9468
# 2     825   Tether USDt   USDT        tether            101997
# 3    1839           BNB    BNB           bnb              2273
# 4    5426        Solana    SOL        solana               776
# 5    3408          USDC   USDC      usd-coin             22753
# 6      52           XRP    XRP           xrp              1413
# 7      74      Dogecoin   DOGE      dogecoin              1090
# 8    1958          TRON    TRX          tron              1059
# 9   11419       Toncoin    TON       toncoin               589
# 10   2010       Cardano    ADA       cardano              1309
# 11   5994     Shiba Inu   SHIB     shiba-inu               895
# 12   5805     Avalanche   AVAX     avalanche               796
# 13   1975     Chainlink   LINK     chainlink              1870
# 14   1831  Bitcoin Cash    BCH  bitcoin-cash               939
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2021-08-26T13:40:22.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2020-08-01T00:00:00.000Z
# 12  2020-07-13T00:00:00.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 9   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 10  [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 11      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 12  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 13  [platform, defi, oracles, smart-contracts, sub...           NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.977532e+07  1.977532e+07            False       NaN         1
# 1         1.204063e+08  1.204063e+08             True       NaN         2
# 2         1.205041e+11  1.223379e+11             True       NaN         3
# 3         1.459309e+08  1.459309e+08            False       NaN         4
# 4         4.703800e+08  5.875381e+08             True       NaN         5
# 5         3.479141e+10  3.479141e+10            False       NaN         6
# 6         5.681186e+10  9.998707e+10            False       NaN         7
# 7         1.465843e+11  1.465842e+11             True       NaN         8
# 8         8.646885e+10  8.646889e+10             True       NaN         9
# 9         2.543854e+09  5.114169e+09             True       NaN        10
# 10        3.498689e+10  4.499521e+10            False       NaN        11
# 11        5.892670e+14  5.895183e+14            False       NaN        12
# 12        4.070832e+08  4.470863e+08            False       NaN        13
# 13        6.268500e+08  1.000000e+09            False       NaN        14
# 14        1.978141e+07  1.978141e+07            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                       7.165966e+10              1.209739e+10      None
# 9                       3.414167e+09              1.703520e+10      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-10-30T16:26:00.000Z     71916.692945          4.866515e+10
# 1   2024-10-30T16:26:00.000Z      2681.318137          2.391533e+10
# 2   2024-10-30T16:26:00.000Z         0.999639          7.949573e+10
# 3   2024-10-30T16:26:00.000Z       596.989812          1.809591e+09
# 4   2024-10-30T16:26:00.000Z       174.114214          3.269233e+09
# 5   2024-10-30T16:26:00.000Z         0.999848          8.642715e+09
# 6   2024-10-30T16:26:00.000Z         0.522371          1.004481e+09
# 7   2024-10-30T16:26:00.000Z         0.165771          3.110709e+09
# 8   2024-10-30T16:26:00.000Z         0.168817          3.983080e+08
# 9   2024-10-30T16:26:00.000Z         4.989562          2.282994e+08
# 10  2024-10-30T16:26:00.000Z         0.355129          3.258804e+08
# 11  2024-10-30T16:26:00.000Z         0.000018          6.569234e+08
# 12  2024-10-30T16:26:00.000Z        26.123346          2.896318e+08
# 13  2024-10-30T16:26:00.000Z        12.168769          3.250658e+08
# 14  2024-10-30T16:26:00.000Z       371.090419          3.903994e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       -8.9953                     0.224717
# 1                        8.4159                     0.159131
# 2                       -4.5054                    -0.005723
# 3                       -0.6112                     0.177929
# 4                      -15.8355                     0.390381
# 5                       -5.4801                    -0.000866
# 6                       -1.7212                     0.179757
# 7                      -20.7336                     0.192282
# 8                        4.0237                     0.194222
# 9                       24.8652                     0.134739
# 10                      12.5342                     0.575576
# 11                      -1.2143                     0.306626
# 12                       6.1901                     0.227013
# 13                      26.2226                    -0.123607
# 14                     -10.3720                     0.212729
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -0.960049                     9.196891
# 1                       1.206644                     6.327013
# 2                      -0.037902                     0.070895
# 3                      -2.058567                     3.376793
# 4                      -4.043190                     4.454753
# 5                      -0.035374                     0.007505
# 6                      -0.855964                     0.098876
# 7                      -6.786945                    20.794220
# 8                       2.121589                     5.651359
# 9                      -1.535405                    -2.273535
# 10                      1.079086                     2.115262
# 11                     -5.115237                     5.178897
# 12                     -2.826325                    -0.933943
# 13                      4.686352                     8.236450
# 14                     -3.974332                     7.503120
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      13.002454                     21.969088
# 1                       2.815195                      6.599695
# 2                      -0.032936                     -0.033059
# 3                       4.171953                     11.786960
# 4                      12.402546                     27.663478
# 5                      -0.010786                     -0.008663
# 6                     -15.801792                     -7.509587
# 7                      40.901013                     63.556871
# 8                       8.071610                      7.417761
# 9                     -14.054187                     -7.286960
# 10                     -6.835083                      1.806102
# 11                      2.981088                     32.713442
# 12                     -7.310993                     13.849098
# 13                      1.516705                      9.752743
# 14                      8.439605                     15.269289
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      14.001582          1.422175e+12
# 1                     -13.842656          3.228476e+11
# 2                       0.033060          1.204606e+11
# 3                       7.185634          8.711928e+10
# 4                       7.696853          8.189984e+10
# 5                      -0.010098          3.478611e+10
# 6                     -10.846896          2.967687e+10
# 7                      43.981527          2.429939e+10
# 8                      32.827891          1.459744e+10
# 9                     -25.997620          1.269272e+10
# 10                     -5.599892          1.242487e+10
# 11                     20.727079          1.082116e+10
# 12                      6.738344          1.063438e+10
# 13                     -2.037577          7.627992e+09
# 14                     -7.697012          7.340690e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          58.7187                        1.510251e+12
# 1                          13.3394                        3.228476e+11
# 2                           4.9772                        1.222938e+11
# 3                           3.5996                        8.711928e+10
# 4                           3.3826                        1.022987e+11
# 5                           1.4367                        3.478611e+10
# 6                           1.2257                        5.223710e+10
# 7                           1.0033                        2.429939e+10
# 8                           0.6029                        1.459744e+10
# 9                           0.5242                        2.551746e+10
# 10                          0.5132                        1.598082e+10
# 11                          0.4471                        1.082577e+10
# 12                          0.4391                        1.869775e+10
# 13                          0.3149                        1.216877e+10
# 14                          0.3031                        7.792899e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 1           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 2           None  2024-10-30T16:26:00.000Z       1027.0      Ethereum
# 3           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 4           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 5           None  2024-10-30T16:26:00.000Z       1027.0      Ethereum
# 6           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 7           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 8           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 9           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 10          None  2024-10-30T16:26:00.000Z          NaN           NaN
# 11          None  2024-10-30T16:26:00.000Z       1027.0      Ethereum
# 12          None  2024-10-30T16:26:00.000Z          NaN           NaN
# 13          None  2024-10-30T16:26:00.000Z       1027.0      Ethereum
# 14          None  2024-10-30T16:26:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 12             NaN           NaN                                         NaN
# 13             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14             NaN           NaN                                         NaN
#
#                    time_stamp
# 0  2024-10-30 17:29:20.229397
# 1  2024-10-30 17:29:20.229397
# 2  2024-10-30 17:29:20.229397
# 3  2024-10-30 17:29:20.229397
# 4  2024-10-30 17:29:20.229397
# 5  2024-10-30 17:29:20.229397
# 6  2024-10-30 17:29:20.229397
# 7  2024-10-30 17:29:20.229397
# 8  2024-10-30 17:29:20.229397
# 9  2024-10-30 17:29:20.229397
# 10 2024-10-30 17:29:20.229397
# 11 2024-10-30 17:29:20.229397
# 12 2024-10-30 17:29:20.229397
# 13 2024-10-30 17:29:20.229397
# 14 2024-10-30 17:29:20.229397

# %%
def api_runner():
  global df
  url ='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
  parameters = {
    'start':'1',
    'limit':'15',
    'convert':'USD'
  }
  headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': API_KEY,
  }

  session = Session()
  session.headers.update(headers)

  try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print(data)
  except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
  
  pd.set_option('display.max_columns',None)
  df2= pd.json_normalirze(data['data'])
  df2['time_stamp']= pd.to_datetime('now')
  df= df.append(df2)

# %%
from time import time
from time import sleep

for i in range (333):
  api_runner()
  print('api runner completed')
  sleep(60)
exit()
# Out:
# {'status': {'timestamp': '2024-10-30T16:51:24.839Z', 'error_code': 0, 'error_message': None, 'elapsed': 35, 'credit_count': 1, 'notice': None, 'total_count': 9904}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11793, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19775315, 'total_supply': 19775315, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T16:49:00.000Z', 'quote': {'USD': {'price': 72139.28205943028, 'volume_24h': 48104315643.73928, 'volume_change_24h': -11.6376, 'percent_change_1h': 0.10124294, 'percent_change_24h': -0.86858522, 'percent_change_7d': 9.55601984, 'percent_change_30d': 13.5368668, 'percent_change_60d': 22.42151658, 'percent_change_90d': 14.68009975, 'market_cap': 1426577026599.0825, 'market_cap_dominance': 58.7102, 'fully_diluted_market_cap': 1514924923248.04, 'tvl': None, 'last_updated': '2024-10-30T16:49:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9468, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120406284.16331623, 'total_supply': 120406284.16331623, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T16:49:00.000Z', 'quote': {'USD': {'price': 2692.60316641915, 'volume_24h': 23892858717.922993, 'volume_change_24h': 7.2361, 'percent_change_1h': 0.18527648, 'percent_change_24h': 1.56557725, 'percent_change_7d': 7.59428346, 'percent_change_30d': 3.38437135, 'percent_change_60d': 7.23487659, 'percent_change_90d': -13.27306687, 'market_cap': 324206341994.90924, 'market_cap_dominance': 13.3426, 'fully_diluted_market_cap': 324206341994.91, 'tvl': None, 'last_updated': '2024-10-30T16:49:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 101997, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 120504138281.46748, 'total_supply': 122337925861.4382, 'platform': {'id': 10 ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 5
#       2 from time import sleep
#       4 for i in range (333):
# ----> 5   api_runner()
#       6   print('api runner completed')
#       7   sleep(60)
#
# File c:\Users\tinka\Desktop\learning\python files\API project.py:25
#      22   print(e)
#      24 pd.set_option('display.max_columns',None)
# ---> 25 df2= pd.json_normalirze(data['data'])
#      26 df2['time_stamp']= pd.to_datetime('now')
#      27 df= df.append(df2)
#
# AttributeError: module 'pandas' has no attribute 'json_normalirze'

# %%
def api_runner():
  
  url ='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
  parameters = {
    'start':'1',
    'limit':'15',
    'convert':'USD'
  }
  headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': API_KEY,
  }

  session = Session()
  session.headers.update(headers)

  try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print(data)
  except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
  global df
  pd.set_option('display.max_columns',None)
  df2= pd.json_normalirze(data['data'])
  df2['time_stamp']= pd.to_datetime('now')
  df= df.append(df2)

# %%
from time import time
from time import sleep

for i in range (333):
  api_runner()
  print('api runner completed')
  sleep(60)
exit()
# Out:
# {'status': {'timestamp': '2024-10-30T16:57:25.962Z', 'error_code': 0, 'error_message': None, 'elapsed': 24, 'credit_count': 1, 'notice': None, 'total_count': 9904}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11793, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19775315, 'total_supply': 19775315, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T16:55:00.000Z', 'quote': {'USD': {'price': 72147.95703549335, 'volume_24h': 47859915432.650475, 'volume_change_24h': -12.4581, 'percent_change_1h': 0.09190764, 'percent_change_24h': -0.85132533, 'percent_change_7d': 9.6419742, 'percent_change_30d': 13.659471, 'percent_change_60d': 22.46240759, 'percent_change_90d': 14.79694706, 'market_cap': 1426748576983.3472, 'market_cap_dominance': 58.6845, 'fully_diluted_market_cap': 1515107097745.36, 'tvl': None, 'last_updated': '2024-10-30T16:55:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9468, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120406284.16331623, 'total_supply': 120406284.16331623, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T16:55:00.000Z', 'quote': {'USD': {'price': 2690.6553894533445, 'volume_24h': 23871508005.66615, 'volume_change_24h': 6.8806, 'percent_change_1h': 0.13765656, 'percent_change_24h': 0.87197194, 'percent_change_7d': 7.93471899, 'percent_change_30d': 3.35580456, 'percent_change_60d': 7.1930449, 'percent_change_90d': -13.29426558, 'market_cap': 323971817408.0777, 'market_cap_dominance': 13.3255, 'fully_diluted_market_cap': 323971817408.08, 'tvl': None, 'last_updated': '2024-10-30T16:55:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 101997, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 120504138281.46748, 'total_supply': 122337925861.4382, 'platform': {'id': 1027 ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 5
#       2 from time import sleep
#       4 for i in range (333):
# ----> 5   api_runner()
#       6   print('api runner completed')
#       7   sleep(60)
#
# File c:\Users\tinka\Desktop\learning\python files\API project.py:25
#      23 global df
#      24 pd.set_option('display.max_columns',None)
# ---> 25 df2= pd.json_normalirze(data['data'])
#      26 df2['time_stamp']= pd.to_datetime('now')
#      27 df= df.append(df2)
#
# AttributeError: module 'pandas' has no attribute 'json_normalirze'

# %%
def api_runner():
  global df
  url ='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
  parameters = {
    'start':'1',
    'limit':'15',
    'convert':'USD'
  }
  headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': API_KEY,
  }

  session = Session()
  session.headers.update(headers)

  try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print(data)
  except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
  
  pd.set_option('display.max_columns',None)
  df2= pd.json_normalize(data['data'])
  df2['time_stamp']= pd.to_datetime('now')
  df= df.append(df2)

# %%
for i in range (333):
  api_runner()
  print('api runner completed')
  sleep(60)
exit()
# Out:
# {'status': {'timestamp': '2024-10-30T17:01:03.665Z', 'error_code': 0, 'error_message': None, 'elapsed': 26, 'credit_count': 1, 'notice': None, 'total_count': 9904}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11793, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19775315, 'total_supply': 19775315, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T16:59:00.000Z', 'quote': {'USD': {'price': 72149.45115932982, 'volume_24h': 47725753072.48515, 'volume_change_24h': -13.0342, 'percent_change_1h': 0.15518185, 'percent_change_24h': -0.7165448, 'percent_change_7d': 9.62173701, 'percent_change_30d': 13.6599994, 'percent_change_60d': 22.39503564, 'percent_change_90d': 14.76205687, 'market_cap': 1426778123752.8625, 'market_cap_dominance': 58.6967, 'fully_diluted_market_cap': 1515138474345.93, 'tvl': None, 'last_updated': '2024-10-30T16:59:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9468, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120406284.16331623, 'total_supply': 120406284.16331623, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T16:59:00.000Z', 'quote': {'USD': {'price': 2690.3950221581204, 'volume_24h': 23781261054.12856, 'volume_change_24h': 5.8244, 'percent_change_1h': 0.24858389, 'percent_change_24h': 0.85821468, 'percent_change_7d': 8.10308274, 'percent_change_30d': 3.32006141, 'percent_change_60d': 7.23478049, 'percent_change_90d': -13.37284506, 'market_cap': 323940467549.5421, 'market_cap_dominance': 13.3272, 'fully_diluted_market_cap': 323940467549.54, 'tvl': None, 'last_updated': '2024-10-30T16:59:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 101997, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 120504138281.46748, 'total_supply': 122337925861.4382, 'platform': {'id': 102 ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-10cdf88464e4> in ?()
#       1 for i in range (333):
# ----> 2   api_runner()
#       3   print('api runner completed')
#       4   sleep(60)
#       5 exit()
#
# <ipython-input-13-e39f02028411> in ?()
#      23
#      24   pd.set_option('display.max_columns',None)
#      25   df2= pd.json_normalize(data['data'])
#      26   df2['time_stamp']= pd.to_datetime('now')
# ---> 27   df= df.append(df2)
#
# c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
type (e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 type (e)
#
# NameError: name 'e' is not defined

# %%
type (data)
# Out:
# dict

# %%
url ='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': API_KEY,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
  list(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-10-30T17:40:59.783Z', 'error_code': 0, 'error_message': None, 'elapsed': 25, 'credit_count': 1, 'notice': None, 'total_count': 9904}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11793, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19775340, 'total_supply': 19775340, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T17:39:00.000Z', 'quote': {'USD': {'price': 71699.33016363964, 'volume_24h': 46340634789.87019, 'volume_change_24h': -16.2971, 'percent_change_1h': -0.41592526, 'percent_change_24h': -1.58712359, 'percent_change_7d': 9.1631397, 'percent_change_30d': 12.83754165, 'percent_change_60d': 21.70759761, 'percent_change_90d': 14.58332439, 'market_cap': 1417878631758.2295, 'market_cap_dominance': 58.6002, 'fully_diluted_market_cap': 1505685933436.43, 'tvl': None, 'last_updated': '2024-10-30T17:39:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9468, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120406284.16331623, 'total_supply': 120406284.16331623, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T17:39:00.000Z', 'quote': {'USD': {'price': 2670.31068990216, 'volume_24h': 23152455502.380413, 'volume_change_24h': 2.1529, 'percent_change_1h': -0.51931831, 'percent_change_24h': -0.02500734, 'percent_change_7d': 6.94389578, 'percent_change_30d': 2.63598975, 'percent_change_60d': 6.64152915, 'percent_change_90d': -13.82847214, 'market_cap': 321522187732.7005, 'market_cap_dominance': 13.2907, 'fully_diluted_market_cap': 321522187732.7, 'tvl': None, 'last_updated': '2024-10-30T17:39:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 101998, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 120504138281.46748, 'total_supply': 122337925861.4382, 'platform': {'id': 1 ...

# %%
type (data)
# Out:
# dict

# %%
url ='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': API_KEY,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
  data=list(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-10-30T17:43:23.990Z', 'error_code': 0, 'error_message': None, 'elapsed': 30, 'credit_count': 1, 'notice': None, 'total_count': 9904}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11793, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19775340, 'total_supply': 19775340, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T17:41:00.000Z', 'quote': {'USD': {'price': 71636.40968269139, 'volume_24h': 46324212164.83552, 'volume_change_24h': -16.3423, 'percent_change_1h': -0.6588204, 'percent_change_24h': -1.70048853, 'percent_change_7d': 9.15609582, 'percent_change_30d': 12.70350919, 'percent_change_60d': 21.59815357, 'percent_change_90d': 14.80894995, 'market_cap': 1416634357854.5144, 'market_cap_dominance': 58.5488, 'fully_diluted_market_cap': 1504364603336.52, 'tvl': None, 'last_updated': '2024-10-30T17:41:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9468, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120406284.16331623, 'total_supply': 120406284.16331623, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T17:41:00.000Z', 'quote': {'USD': {'price': 2663.3596900730636, 'volume_24h': 23149762809.16053, 'volume_change_24h': 2.1324, 'percent_change_1h': -1.14986824, 'percent_change_24h': -0.27959496, 'percent_change_7d': 6.76799147, 'percent_change_30d': 2.29957269, 'percent_change_60d': 6.33463163, 'percent_change_90d': -13.84987963, 'market_cap': 320685243672.05914, 'market_cap_dominance': 13.2538, 'fully_diluted_market_cap': 320685243672.06, 'tvl': None, 'last_updated': '2024-10-30T17:41:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 101998, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 120504138281.46748, 'total_supply': 122337925861.4382, 'platform': {'id' ...

# %%
type (data)
# Out:
# list

# %%
def api_runner():
  global df
  url ='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
  parameters = {
    'start':'1',
    'limit':'15',
    'convert':'USD'
  }
  headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': API_KEY,
  }

  session = Session()
  session.headers.update(headers)

  try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    data=list(data)
    print(data)
  except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
  
  pd.set_option('display.max_columns',None)
  df2= pd.json_normalize(data['data'])
  df2['time_stamp']=pd.to_datetime('now')

  df = pd.concat([df, df2])

# %%
from time import time
from time import sleep

for i in range (333):
  api_runner()
  print('api runner completed')
  sleep(60)
exit()
# Out:
# ['status', 'data']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       2 from time import sleep
#       4 for i in range (333):
# ----> 5   api_runner()
#       6   print('api runner completed')
#       7   sleep(60)
#
# Cell In[23], line 26, in api_runner()
#      23   print(e)
#      25 pd.set_option('display.max_columns',None)
# ---> 26 df2= pd.json_normalize(data['data'])
#      27 df2['time_stamp']=pd.to_datetime('now')
#      29 df = pd.concat([df, df2])
#
# TypeError: list indices must be integers or slices, not str

# %%
def api_runner():
  global df
  url ='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
  parameters = {
    'start':'1',
    'limit':'15',
    'convert':'USD'
  }
  headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': API_KEY,
  }

  session = Session()
  session.headers.update(headers)

  try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print(data)
  except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
  
  pd.set_option('display.max_columns',None)
  df2= pd.json_normalize(data['data'])
  df2['time_stamp']=pd.to_datetime('now')

  df = pd.concat([df, df2])

# %%
for i in range (333):
  api_runner()
  print('api runner completed')
  sleep(60)
exit()
# Out:
# {'status': {'timestamp': '2024-10-30T17:53:42.415Z', 'error_code': 0, 'error_message': None, 'elapsed': 36, 'credit_count': 1, 'notice': None, 'total_count': 9904}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11793, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19775340, 'total_supply': 19775340, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T17:52:00.000Z', 'quote': {'USD': {'price': 71802.89110306703, 'volume_24h': 46093334259.92749, 'volume_change_24h': -16.8937, 'percent_change_1h': -0.49568322, 'percent_change_24h': -1.18103133, 'percent_change_7d': 9.166968, 'percent_change_30d': 12.89582457, 'percent_change_60d': 22.15666987, 'percent_change_90d': 14.23502449, 'market_cap': 1419926584546.1255, 'market_cap_dominance': 58.6487, 'fully_diluted_market_cap': 1507860713164.41, 'tvl': None, 'last_updated': '2024-10-30T17:52:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9468, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120406284.16331623, 'total_supply': 120406284.16331623, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-30T17:52:00.000Z', 'quote': {'USD': {'price': 2673.1004160109833, 'volume_24h': 23173928631.73669, 'volume_change_24h': 2.1778, 'percent_change_1h': -0.72009634, 'percent_change_24h': 0.55115053, 'percent_change_7d': 6.89340935, 'percent_change_30d': 2.61763537, 'percent_change_60d': 7.17839804, 'percent_change_90d': -13.97851394, 'market_cap': 321858088287.2973, 'market_cap_dominance': 13.294, 'fully_diluted_market_cap': 321858088287.3, 'tvl': None, 'last_updated': '2024-10-30T17:52:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 101998, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 120504138281.46748, 'total_supply': 122337925861.4382, 'platform': {'id': 102 ...
# api runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 4
#       2   api_runner()
#       3   print('api runner completed')
# ----> 4   sleep(60)
#       5 exit()
#
# KeyboardInterrupt:

# %%
def api_runner():
  global df
  url ='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
  parameters = {
    'start':'1',
    'limit':'15',
    'convert':'USD'
  }
  headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': API_KEY,
  }

  session = Session()
  session.headers.update(headers)

  try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
  except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
  
  pd.set_option('display.max_columns',None)
  df2= pd.json_normalize(data['data'])
  df2['time_stamp']=pd.to_datetime('now')

  df = pd.concat([df, df2])

# %%
for i in range (333):
  api_runner()
  print('api runner completed')
  sleep(60)
exit()
# Out:
# HTTPSConnectionPool(host='pro-api.coinmarketcap.com', port=443): Max retries exceeded with url: /v1/cryptocurrency/listings/latest?start=1&limit=15&convert=USD (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001A56338F410>: Failed to resolve 'pro-api.coinmarketcap.com' ([Errno 11001] getaddrinfo failed)"))
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[28], line 2
#       1 for i in range (333):
# ----> 2   api_runner()
#       3   print('api runner completed')
#       4   sleep(60)
#
# Cell In[27], line 24, in api_runner()
#      21   print(e)
#      23 pd.set_option('display.max_columns',None)
# ---> 24 df2= pd.json_normalize(data['data'])
#      25 df2['time_stamp']=pd.to_datetime('now')
#      27 df = pd.concat([df, df2])
#
# UnboundLocalError: cannot access local variable 'data' where it is not associated with a value

# %%
for i in range (333):
  api_runner()
  print('api runner completed')
  sleep(60)
exit()
# Out:
# api runner completed
# api runner completed
# api runner completed
# api runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 4
#       2   api_runner()
#       3   print('api runner completed')
# ----> 4   sleep(60)
#       5 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#       id          name symbol          slug  num_market_pairs  \
# 0      1       Bitcoin    BTC       bitcoin             11793
# 1   1027      Ethereum    ETH      ethereum              9468
# 2    825   Tether USDt   USDT        tether            101997
# 3   1839           BNB    BNB           bnb              2273
# 4   5426        Solana    SOL        solana               776
# ..   ...           ...    ...           ...               ...
# 10  2010       Cardano    ADA       cardano              1309
# 11  5994     Shiba Inu   SHIB     shiba-inu               895
# 12  5805     Avalanche   AVAX     avalanche               796
# 13  1975     Chainlink   LINK     chainlink              1870
# 14  1831  Bitcoin Cash    BCH  bitcoin-cash               939
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# ..                       ...
# 10  2017-10-01T00:00:00.000Z
# 11  2020-08-01T00:00:00.000Z
# 12  2020-07-13T00:00:00.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# ..                                                ...           ...
# 10  [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 11      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 12  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 13  [platform, defi, oracles, smart-contracts, sub...           NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.977532e+07  1.977532e+07            False       NaN         1
# 1         1.204063e+08  1.204063e+08             True       NaN         2
# 2         1.205041e+11  1.223379e+11             True       NaN         3
# 3         1.459309e+08  1.459309e+08            False       NaN         4
# 4         4.703800e+08  5.875381e+08             True       NaN         5
# ..                 ...           ...              ...       ...       ...
# 10        3.498689e+10  4.499521e+10            False       NaN        11
# 11        5.892670e+14  5.895183e+14            False       NaN        12
# 12        4.070836e+08  4.470867e+08            False       NaN        13
# 13        6.268500e+08  1.000000e+09            False       NaN        14
# 14        1.978144e+07  1.978144e+07            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# ..                               ...                       ...       ...
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-10-30T16:26:00.000Z     71916.692945          4.866515e+10
# 1   2024-10-30T16:26:00.000Z      2681.318137          2.391533e+10
# 2   2024-10-30T16:26:00.000Z         0.999639          7.949573e+10
# 3   2024-10-30T16:26:00.000Z       596.989812          1.809591e+09
# 4   2024-10-30T16:26:00.000Z       174.114214          3.269233e+09
# ..                       ...              ...                   ...
# 10  2024-10-30T18:04:00.000Z         0.356055          3.184412e+08
# 11  2024-10-30T18:04:00.000Z         0.000018          5.455744e+08
# 12  2024-10-30T18:04:00.000Z        26.186667          2.721712e+08
# 13  2024-10-30T18:04:00.000Z        12.200106          3.176882e+08
# 14  2024-10-30T18:04:00.000Z       371.088961          3.807796e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       -8.9953                     0.224717
# 1                        8.4159                     0.159131
# 2                       -4.5054                    -0.005723
# 3                       -0.6112                     0.177929
# 4                      -15.8355                     0.390381
# ..                          ...                          ...
# 10                       8.7523                    -0.247398
# 11                     -28.2026                     0.161866
# 12                      -2.3960                    -0.182890
# 13                      20.1636                    -0.610961
# 14                     -12.6504                    -0.035238
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -0.960049                     9.196891
# 1                       1.206644                     6.327013
# 2                      -0.037902                     0.070895
# 3                      -2.058567                     3.376793
# 4                      -4.043190                     4.454753
# ..                           ...                          ...
# 10                      0.748121                     3.178313
# 11                     -4.437584                     7.227035
# 12                     -3.062145                     0.639087
# 13                      5.109004                     9.820496
# 14                     -3.630480                     8.676328
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      13.002454                     21.969088
# 1                       2.815195                      6.599695
# 2                      -0.032936                     -0.033059
# 3                       4.171953                     11.786960
# 4                      12.402546                     27.663478
# ..                           ...                           ...
# 10                     -6.711818                      2.573076
# 11                      3.334336                     33.877870
# 12                     -7.186078                     15.999708
# 13                      1.741634                     10.984914
# 14                      8.205949                     15.272222
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      14.001582          1.422175e+12
# 1                     -13.842656          3.228476e+11
# 2                       0.033060          1.204606e+11
# 3                       7.185634          8.711928e+10
# 4                       7.696853          8.189984e+10
# ..                           ...                   ...
# 10                     -5.112212          1.245724e+10
# 11                     22.352638          1.088400e+10
# 12                      7.139812          1.066016e+10
# 13                     -1.027709          7.647636e+09
# 14                     -5.955245          7.340674e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          58.7187                        1.510251e+12
# 1                          13.3394                        3.228476e+11
# 2                           4.9772                        1.222938e+11
# 3                           3.5996                        8.711928e+10
# 4                           3.3826                        1.022987e+11
# ..                             ...                                 ...
# 10                          0.5139                        1.602246e+10
# 11                          0.4491                        1.088865e+10
# 12                          0.4398                        1.874307e+10
# 13                          0.3155                        1.220011e+10
# 14                          0.3029                        7.792868e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 1           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 2           None  2024-10-30T16:26:00.000Z       1027.0      Ethereum
# 3           None  2024-10-30T16:26:00.000Z          NaN           NaN
# 4           None  2024-10-30T16:26:00.000Z          NaN           NaN
# ..           ...                       ...          ...           ...
# 10          None  2024-10-30T18:04:00.000Z          NaN           NaN
# 11          None  2024-10-30T18:04:00.000Z       1027.0      Ethereum
# 12          None  2024-10-30T18:04:00.000Z          NaN           NaN
# 13          None  2024-10-30T18:04:00.000Z       1027.0      Ethereum
# 14          None  2024-10-30T18:04:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# ..             ...           ...                                         ...
# 10             NaN           NaN                                         NaN
# 11             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 12             NaN           NaN                                         NaN
# 13             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14             NaN           NaN                                         NaN
#
#                    time_stamp
# 0  2024-10-30 17:29:20.229397
# 1  2024-10-30 17:29:20.229397
# 2  2024-10-30 17:29:20.229397
# 3  2024-10-30 17:29:20.229397
# 4  2024-10-30 17:29:20.229397
# ..                        ...
# 10 2024-10-30 19:06:13.146040
# 11 2024-10-30 19:06:13.146040
# 12 2024-10-30 19:06:13.146040
# 13 2024-10-30 19:06:13.146040
# 14 2024-10-30 19:06:13.146040
#
# [90 rows x 37 columns]

# %%
def api_runner():
  global df
  url ='https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
  parameters = {
    'start':'1',
    'limit':'15',
    'convert':'USD'
  }
  headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': API_KEY,
  }

  session = Session()
  session.headers.update(headers)

  try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
  except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
  
  pd.set_option('display.max_columns',None)
  df= pd.json_normalize(data['data'])
  df['time_stamp']=pd.to_datetime('now')
  df
  
  if not os.path.isfile(r'C:\Users\tinka\Desktop\learning\Sheets\crypto API.csv'):
    df.to_csv(r'C:\Users\tinka\Desktop\learning\Sheets\crypto API.csv',header='column_names')
  else:
    df.to_csv(r'C:\Users\tinka\Desktop\learning\Sheets\crypto API.csv',mode='a',header=False)

# %%
for i in range (333):
  api_runner()
  print('api runner completed')
  sleep(60)
exit()
# Out:
# HTTPSConnectionPool(host='pro-api.coinmarketcap.com', port=443): Max retries exceeded with url: /v1/cryptocurrency/listings/latest?start=1&limit=15&convert=USD (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001A5633DC710>: Failed to resolve 'pro-api.coinmarketcap.com' ([Errno 11001] getaddrinfo failed)"))
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[32], line 2
#       1 for i in range (333):
# ----> 2   api_runner()
#       3   print('api runner completed')
#       4   sleep(60)
#
# Cell In[31], line 24, in api_runner()
#      21   print(e)
#      23 pd.set_option('display.max_columns',None)
# ---> 24 df= pd.json_normalize(data['data'])
#      25 df['time_stamp']=pd.to_datetime('now')
#      26 df
#
# UnboundLocalError: cannot access local variable 'data' where it is not associated with a value

# %%
for i in range (333):
  api_runner()
  print('api runner completed')
  sleep(60)
exit()
# Out:
# api runner completed
# api runner completed
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 for i in range (333):
# ----> 2   api_runner()
#       3   print('api runner completed')
#       4   sleep(60)
#
# Cell In[31], line 18, in api_runner()
#      15 session.headers.update(headers)
#      17 try:
# ---> 18   response = session.get(url, params=parameters)
#      19   data = json.loads(response.text)
#      20 except (ConnectionError, Timeout, TooManyRedirects) as e:
#
# File c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\urllib3\connection.py:615, in HTTPSConnection.connect(self)
#     613 def connect(self) -> None:
#     614     sock: socket.socket | ssl.SSLSocket
# --> 615     self.sock = sock = self._new_conn()
#     616     server_hostname: str = self.host
#     617     tls_in_tls = False
#
# File c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     191 """Establish a socket connection and set nodelay settings on it.
#     192
#     193 :return: New socket connection.
#     194 """
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#     203     raise NameResolutionError(self.host, self, e) from e
#
# File c:\Users\tinka\Desktop\learning\.venv\Lib\site-packages\urllib3\util\connection.py:81, in create_connection(address, timeout, source_address, socket_options)
#      79         err = _
#      80         if sock is not None:
# ---> 81             sock.close()
#      83 if err is not None:
#      84     try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:501, in socket.close(self)
#     497 def _real_close(self, _ss=_socket.socket):
#     498     # This function should not reference any globals. See issue #808164.
#     499     _ss.close(self)
# --> 501 def close(self):
#     502     # This function should not reference any globals. See issue #808164.
#     503     self._closed = True
#     504     if self._io_refs <= 0:
#
# KeyboardInterrupt:

# %%
pd.read_csv(r'C:\Users\tinka\Desktop\learning\Sheets\crypto API.csv')
# Out:
#     Unnamed: 0     id          name symbol          slug  num_market_pairs  \
# 0            0      1       Bitcoin    BTC       bitcoin             11793
# 1            1   1027      Ethereum    ETH      ethereum              9468
# 2            2    825   Tether USDt   USDT        tether            101999
# 3            3   1839           BNB    BNB           bnb              2273
# 4            4   5426        Solana    SOL        solana               776
# 5            5   3408          USDC   USDC      usd-coin             22753
# 6            6     52           XRP    XRP           xrp              1413
# 7            7     74      Dogecoin   DOGE      dogecoin              1090
# 8            8   1958          TRON    TRX          tron              1059
# 9            9  11419       Toncoin    TON       toncoin               589
# 10          10   2010       Cardano    ADA       cardano              1310
# 11          11   5994     Shiba Inu   SHIB     shiba-inu               895
# 12          12   5805     Avalanche   AVAX     avalanche               796
# 13          13   1975     Chainlink   LINK     chainlink              1870
# 14          14   1831  Bitcoin Cash    BCH  bitcoin-cash               939
# 15           0      1       Bitcoin    BTC       bitcoin             11793
# 16           1   1027      Ethereum    ETH      ethereum              9468
# 17           2    825   Tether USDt   USDT        tether            101999
# 18           3   1839           BNB    BNB           bnb              2273
# 19           4   5426        Solana    SOL        solana               776
# 20           5   3408          USDC   USDC      usd-coin             22753
# 21           6     52           XRP    XRP           xrp              1413
# 22           7     74      Dogecoin   DOGE      dogecoin              1090
# 23           8   1958          TRON    TRX          tron              1059
# 24           9  11419       Toncoin    TON       toncoin               589
# 25          10   2010       Cardano    ADA       cardano              1310
# 26          11   5994     Shiba Inu   SHIB     shiba-inu               895
# 27          12   5805     Avalanche   AVAX     avalanche               796
# 28          13   1975     Chainlink   LINK     chainlink              1870
# 29          14   1831  Bitcoin Cash    BCH  bitcoin-cash               939
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2021-08-26T13:40:22.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2020-08-01T00:00:00.000Z
# 12  2020-07-13T00:00:00.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
# 15  2010-07-13T00:00:00.000Z
# 16  2015-08-07T00:00:00.000Z
# 17  2015-02-25T00:00:00.000Z
# 18  2017-07-25T00:00:00.000Z
# 19  2020-04-10T00:00:00.000Z
# 20  2018-10-08T00:00:00.000Z
# 21  2013-08-04T00:00:00.000Z
# 22  2013-12-15T00:00:00.000Z
# 23  2017-09-13T00:00:00.000Z
# 24  2021-08-26T13:40:22.000Z
# 25  2017-10-01T00:00:00.000Z
# 26  2020-08-01T00:00:00.000Z
# 27  2020-07-13T00:00:00.000Z
# 28  2017-09-20T00:00:00.000Z
# 29  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   ['mineable', 'pow', 'sha-256', 'store-of-value...  2.100000e+07
# 1   ['pos', 'smart-contracts', 'ethereum-ecosystem...           NaN
# 2   ['stablecoin', 'asset-backed-stablecoin', 'ava...           NaN
# 3   ['marketplace', 'centralized-exchange', 'payme...           NaN
# 4   ['pos', 'platform', 'solana-ecosystem', 'cms-h...           NaN
# 5   ['medium-of-exchange', 'stablecoin', 'asset-ba...           NaN
# 6   ['medium-of-exchange', 'enterprise-solutions',...  1.000000e+11
# 7   ['mineable', 'pow', 'scrypt', 'medium-of-excha...           NaN
# 8   ['media', 'payments', 'tron-ecosystem', 'layer...           NaN
# 9   ['pos', 'layer-1', 'ftx-bankruptcy-estate', 'd...           NaN
# 10  ['dpos', 'pos', 'platform', 'research', 'smart...  4.500000e+10
# 11  ['memes', 'ethereum-ecosystem', 'doggone-dogge...           NaN
# 12  ['defi', 'smart-contracts', 'three-arrows-capi...  7.157487e+08
# 13  ['platform', 'defi', 'oracles', 'smart-contrac...           NaN
# 14  ['mineable', 'pow', 'sha-256', 'marketplace', ...  2.100000e+07
# 15  ['mineable', 'pow', 'sha-256', 'store-of-value...  2.100000e+07
# 16  ['pos', 'smart-contracts', 'ethereum-ecosystem...           NaN
# 17  ['stablecoin', 'asset-backed-stablecoin', 'ava...           NaN
# 18  ['marketplace', 'centralized-exchange', 'payme...           NaN
# 19  ['pos', 'platform', 'solana-ecosystem', 'cms-h...           NaN
# 20  ['medium-of-exchange', 'stablecoin', 'asset-ba...           NaN
# 21  ['medium-of-exchange', 'enterprise-solutions',...  1.000000e+11
# 22  ['mineable', 'pow', 'scrypt', 'medium-of-excha...           NaN
# 23  ['media', 'payments', 'tron-ecosystem', 'layer...           NaN
# 24  ['pos', 'layer-1', 'ftx-bankruptcy-estate', 'd...           NaN
# 25  ['dpos', 'pos', 'platform', 'research', 'smart...  4.500000e+10
# 26  ['memes', 'ethereum-ecosystem', 'doggone-dogge...           NaN
# 27  ['defi', 'smart-contracts', 'three-arrows-capi...  7.157487e+08
# 28  ['platform', 'defi', 'oracles', 'smart-contrac...           NaN
# 29  ['mineable', 'pow', 'sha-256', 'marketplace', ...  2.100000e+07
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.977536e+07  1.977536e+07            False       NaN         1
# 1         1.204063e+08  1.204063e+08             True       NaN         2
# 2         1.205041e+11  1.223379e+11             True       NaN         3
# 3         1.459309e+08  1.459309e+08            False       NaN         4
# 4         4.703782e+08  5.875367e+08             True       NaN         5
# 5         3.483197e+10  3.483197e+10            False       NaN         6
# 6         5.681186e+10  9.998707e+10            False       NaN         7
# 7         1.465857e+11  1.465857e+11             True       NaN         8
# 8         8.646809e+10  8.646811e+10             True       NaN         9
# 9         2.543862e+09  5.114176e+09             True       NaN        10
# 10        3.498689e+10  4.499521e+10            False       NaN        11
# 11        5.892670e+14  5.895183e+14            False       NaN        12
# 12        4.070836e+08  4.470867e+08            False       NaN        13
# 13        6.268500e+08  1.000000e+09            False       NaN        14
# 14        1.978147e+07  1.978147e+07            False       NaN        15
# 15        1.977536e+07  1.977536e+07            False       NaN         1
# 16        1.204063e+08  1.204063e+08             True       NaN         2
# 17        1.205041e+11  1.223379e+11             True       NaN         3
# 18        1.459309e+08  1.459309e+08            False       NaN         4
# 19        4.703782e+08  5.875367e+08             True       NaN         5
# 20        3.483197e+10  3.483197e+10            False       NaN         6
# 21        5.681186e+10  9.998707e+10            False       NaN         7
# 22        1.465857e+11  1.465857e+11             True       NaN         8
# 23        8.646809e+10  8.646811e+10             True       NaN         9
# 24        2.543862e+09  5.114176e+09             True       NaN        10
# 25        3.498689e+10  4.499521e+10            False       NaN        11
# 26        5.892670e+14  5.895183e+14            False       NaN        12
# 27        4.070836e+08  4.470867e+08            False       NaN        13
# 28        6.268500e+08  1.000000e+09            False       NaN        14
# 29        1.978147e+07  1.978147e+07            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                                NaN                       NaN        NaN
# 1                                NaN                       NaN        NaN
# 2                                NaN                       NaN        NaN
# 3                                NaN                       NaN        NaN
# 4                                NaN                       NaN        NaN
# 5                                NaN                       NaN        NaN
# 6                                NaN                       NaN        NaN
# 7                                NaN                       NaN        NaN
# 8                       7.165966e+10              1.211767e+10        NaN
# 9                       3.414167e+09              1.703494e+10        NaN
# 10                               NaN                       NaN        NaN
# 11                               NaN                       NaN        NaN
# 12                               NaN                       NaN        NaN
# 13                               NaN                       NaN        NaN
# 14                               NaN                       NaN        NaN
# 15                               NaN                       NaN        NaN
# 16                               NaN                       NaN        NaN
# 17                               NaN                       NaN        NaN
# 18                               NaN                       NaN        NaN
# 19                               NaN                       NaN        NaN
# 20                               NaN                       NaN        NaN
# 21                               NaN                       NaN        NaN
# 22                               NaN                       NaN        NaN
# 23                      7.165966e+10              1.211786e+10        NaN
# 24                      3.414167e+09              1.702927e+10        NaN
# 25                               NaN                       NaN        NaN
# 26                               NaN                       NaN        NaN
# 27                               NaN                       NaN        NaN
# 28                               NaN                       NaN        NaN
# 29                               NaN                       NaN        NaN
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-10-30T18:52:00.000Z     71897.134680          4.446764e+10
# 1   2024-10-30T18:52:00.000Z      2666.234430          2.276855e+10
# 2   2024-10-30T18:52:00.000Z         0.999658          7.375155e+10
# 3   2024-10-30T18:52:00.000Z       599.013352          1.738198e+09
# 4   2024-10-30T18:52:00.000Z       174.259118          3.003650e+09
# 5   2024-10-30T18:52:00.000Z         0.999895          8.058853e+09
# 6   2024-10-30T18:52:00.000Z         0.522959          9.751751e+08
# 7   2024-10-30T18:52:00.000Z         0.167783          2.734341e+09
# 8   2024-10-30T18:52:00.000Z         0.169100          3.948525e+08
# 9   2024-10-30T18:52:00.000Z         4.989488          2.155360e+08
# 10  2024-10-30T18:52:00.000Z         0.355932          3.155287e+08
# 11  2024-10-30T18:52:00.000Z         0.000018          5.252286e+08
# 12  2024-10-30T18:52:00.000Z        26.216780          2.681201e+08
# 13  2024-10-30T18:52:00.000Z        12.222007          3.167930e+08
# 14  2024-10-30T18:52:00.000Z       372.656638          3.791047e+08
# 15  2024-10-30T18:53:00.000Z     71909.069685          4.445894e+10
# 16  2024-10-30T18:53:00.000Z      2667.255583          2.280327e+10
# 17  2024-10-30T18:53:00.000Z         0.999572          7.376432e+10
# 18  2024-10-30T18:53:00.000Z       599.039816          1.736984e+09
# 19  2024-10-30T18:53:00.000Z       174.291909          3.005015e+09
# 20  2024-10-30T18:53:00.000Z         0.999824          8.062647e+09
# 21  2024-10-30T18:53:00.000Z         0.522969          9.747809e+08
# 22  2024-10-30T18:53:00.000Z         0.167802          2.733494e+09
# 23  2024-10-30T18:53:00.000Z         0.169103          3.948374e+08
# 24  2024-10-30T18:53:00.000Z         4.987827          2.154575e+08
# 25  2024-10-30T18:53:00.000Z         0.355920          3.155050e+08
# 26  2024-10-30T18:53:00.000Z         0.000018          5.245331e+08
# 27  2024-10-30T18:53:00.000Z        26.213950          2.680704e+08
# 28  2024-10-30T18:53:00.000Z        12.221448          3.169129e+08
# 29  2024-10-30T18:53:00.000Z       372.641283          3.791194e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -21.7137                     0.131253
# 1                       -0.9883                    -0.256855
# 2                      -15.8375                    -0.009490
# 3                       -7.5484                     0.208726
# 4                      -26.3924                    -0.437190
# 5                      -15.2264                     0.002582
# 6                       -7.3686                     0.026524
# 7                      -33.8413                     0.560002
# 8                        0.0488                     0.042589
# 9                       12.5079                     0.218067
# 10                       6.1929                     0.094009
# 11                     -32.0344                     0.079552
# 12                      -5.1381                     0.132482
# 13                      18.8807                     0.073770
# 14                     -13.8167                     0.547812
# 15                     -21.8233                     0.177686
# 16                      -0.8808                    -0.160020
# 17                     -15.8943                    -0.005557
# 18                      -7.6513                     0.233642
# 19                     -26.4869                    -0.402724
# 20                     -15.2544                    -0.009421
# 21                      -7.4676                     0.028377
# 22                     -33.8416                     0.575586
# 23                       0.0389                     0.044571
# 24                      12.3079                     0.190040
# 25                       6.1085                     0.096629
# 26                     -32.2418                     0.126905
# 27                      -5.2115                     0.134815
# 28                      18.9100                     0.112716
# 29                     -13.8227                     0.543421
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -1.601024                     9.190675
# 1                       0.199971                     7.293802
# 2                      -0.018581                     0.102949
# 3                      -1.474920                     3.798993
# 4                      -4.048621                     2.968054
# 5                      -0.003890                    -0.001048
# 6                      -1.316060                     1.335063
# 7                      -4.389437                    23.501073
# 8                       1.987701                     6.141343
# 9                      -2.660639                    -1.389137
# 10                      0.547840                     2.737297
# 11                     -4.205025                     6.807915
# 12                     -3.043031                    -0.041060
# 13                      4.995112                    10.191292
# 14                     -3.408794                     8.843057
# 15                     -1.586965                     9.174444
# 16                      0.250701                     7.349448
# 17                     -0.022102                     0.101347
# 18                     -1.473965                     3.811070
# 19                     -4.041893                     3.008069
# 20                     -0.012639                     0.012891
# 21                     -1.325296                     1.335761
# 22                     -4.386064                    23.510095
# 23                      1.976529                     6.142131
# 24                     -2.696769                    -1.421585
# 25                      0.533822                     2.727729
# 26                     -4.224967                     6.829414
# 27                     -3.046419                    -0.059627
# 28                      4.989422                    10.183438
# 29                     -3.433451                     8.834162
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      13.498569                     22.007475
# 1                       3.045628                      6.659578
# 2                      -0.002907                     -0.054556
# 3                       4.883219                     12.345419
# 4                      12.404919                     28.465317
# 5                      -0.002685                     -0.025727
# 6                     -15.716049                     -7.682154
# 7                      42.195183                     64.738469
# 8                       8.101822                      7.161048
# 9                     -14.583762                     -7.497397
# 10                     -6.375644                      2.544159
# 11                      3.510182                     33.611705
# 12                     -6.867890                     15.705934
# 13                      2.221958                     11.011830
# 14                      8.921160                     15.480930
# 15                     13.566771                     22.096972
# 16                      3.133919                      6.834930
# 17                     -0.013686                     -0.062826
# 18                      4.905730                     12.383490
# 19                     12.435102                     28.545670
# 20                     -0.003209                     -0.037488
# 21                    -15.718413                     -7.672644
# 22                     42.234389                     64.841148
# 23                      8.104109                      7.156689
# 24                    -14.598210                     -7.504141
# 25                     -6.383313                      2.563899
# 26                      3.544213                     33.696272
# 27                     -6.877070                     15.737026
# 28                      2.177637                     11.028790
# 29                      8.923348                     15.504752
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      14.385826          1.421792e+12
# 1                     -13.649398          3.210314e+11
# 2                       0.062117          1.204629e+11
# 3                       8.086492          8.741458e+10
# 4                       9.505981          8.196769e+10
# 5                       0.004905          3.482830e+10
# 6                      -8.910425          2.971029e+10
# 7                      47.984812          2.459455e+10
# 8                      32.732930          1.462178e+10
# 9                     -25.208023          1.269257e+10
# 10                     -3.842879          1.245294e+10
# 11                     23.073548          1.087981e+10
# 12                      8.279252          1.067242e+10
# 13                      0.097041          7.661364e+09
# 14                     -4.570478          7.371696e+09
# 15                     14.517991          1.422028e+12
# 16                    -13.507880          3.211543e+11
# 17                      0.047315          1.204526e+11
# 18                      8.139662          8.741844e+10
# 19                      9.596142          8.198311e+10
# 20                     -0.013263          3.482583e+10
# 21                     -8.907178          2.971083e+10
# 22                     48.071543          2.459743e+10
# 23                     32.734860          1.462201e+10
# 24                    -25.221666          1.268834e+10
# 25                     -3.825246          1.245255e+10
# 26                     23.119972          1.088210e+10
# 27                      8.281728          1.067127e+10
# 28                      0.140580          7.661014e+09
# 29                     -4.576264          7.371392e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          58.6133                        1.509840e+12
# 1                          13.2345                        3.210314e+11
# 2                           4.9689                        1.222960e+11
# 3                           3.6057                        8.741458e+10
# 4                           3.3755                        1.023836e+11
# 5                           1.4343                        3.482830e+10
# 6                           1.2235                        5.229593e+10
# 7                           1.0139                        2.459455e+10
# 8                           0.6021                        1.462178e+10
# 9                           0.5227                        2.551712e+10
# 10                          0.5128                        1.601692e+10
# 11                          0.4478                        1.088445e+10
# 12                          0.4400                        1.876463e+10
# 13                          0.3158                        1.222201e+10
# 14                          0.3039                        7.825789e+09
# 15                         58.6230                        1.510090e+12
# 16                         13.2396                        3.211543e+11
# 17                          4.9657                        1.222856e+11
# 18                          3.6038                        8.741844e+10
# 19                          3.3762                        1.024029e+11
# 20                          1.4342                        3.482583e+10
# 21                          1.2235                        5.229687e+10
# 22                          1.0140                        2.459743e+10
# 23                          0.6022                        1.462201e+10
# 24                          0.5225                        2.550863e+10
# 25                          0.5128                        1.601642e+10
# 26                          0.4492                        1.088674e+10
# 27                          0.4399                        1.876260e+10
# 28                          0.3158                        1.222145e+10
# 29                          0.3039                        7.825467e+09
#
#     quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0             NaN  2024-10-30T18:52:00.000Z          NaN           NaN
# 1             NaN  2024-10-30T18:52:00.000Z          NaN           NaN
# 2             NaN  2024-10-30T18:52:00.000Z       1027.0      Ethereum
# 3             NaN  2024-10-30T18:52:00.000Z          NaN           NaN
# 4             NaN  2024-10-30T18:52:00.000Z          NaN           NaN
# 5             NaN  2024-10-30T18:52:00.000Z       1027.0      Ethereum
# 6             NaN  2024-10-30T18:52:00.000Z          NaN           NaN
# 7             NaN  2024-10-30T18:52:00.000Z          NaN           NaN
# 8             NaN  2024-10-30T18:52:00.000Z          NaN           NaN
# 9             NaN  2024-10-30T18:52:00.000Z          NaN           NaN
# 10            NaN  2024-10-30T18:52:00.000Z          NaN           NaN
# 11            NaN  2024-10-30T18:52:00.000Z       1027.0      Ethereum
# 12            NaN  2024-10-30T18:52:00.000Z          NaN           NaN
# 13            NaN  2024-10-30T18:52:00.000Z       1027.0      Ethereum
# 14            NaN  2024-10-30T18:52:00.000Z          NaN           NaN
# 15            NaN  2024-10-30T18:53:00.000Z          NaN           NaN
# 16            NaN  2024-10-30T18:53:00.000Z          NaN           NaN
# 17            NaN  2024-10-30T18:53:00.000Z       1027.0      Ethereum
# 18            NaN  2024-10-30T18:53:00.000Z          NaN           NaN
# 19            NaN  2024-10-30T18:53:00.000Z          NaN           NaN
# 20            NaN  2024-10-30T18:53:00.000Z       1027.0      Ethereum
# 21            NaN  2024-10-30T18:53:00.000Z          NaN           NaN
# 22            NaN  2024-10-30T18:53:00.000Z          NaN           NaN
# 23            NaN  2024-10-30T18:53:00.000Z          NaN           NaN
# 24            NaN  2024-10-30T18:53:00.000Z          NaN           NaN
# 25            NaN  2024-10-30T18:53:00.000Z          NaN           NaN
# 26            NaN  2024-10-30T18:53:00.000Z       1027.0      Ethereum
# 27            NaN  2024-10-30T18:53:00.000Z          NaN           NaN
# 28            NaN  2024-10-30T18:53:00.000Z       1027.0      Ethereum
# 29            NaN  2024-10-30T18:53:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 12             NaN           NaN                                         NaN
# 13             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14             NaN           NaN                                         NaN
# 15             NaN           NaN                                         NaN
# 16             NaN           NaN                                         NaN
# 17             ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 18             NaN           NaN                                         NaN
# 19             NaN           NaN                                         NaN
# 20             ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 21             NaN           NaN                                         NaN
# 22             NaN           NaN                                         NaN
# 23             NaN           NaN                                         NaN
# 24             NaN           NaN                                         NaN
# 25             NaN           NaN                                         NaN
# 26             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 27             NaN           NaN                                         NaN
# 28             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 29             NaN           NaN                                         NaN
#
#                     time_stamp
# 0   2024-10-30 19:53:34.460232
# 1   2024-10-30 19:53:34.460232
# 2   2024-10-30 19:53:34.460232
# 3   2024-10-30 19:53:34.460232
# 4   2024-10-30 19:53:34.460232
# 5   2024-10-30 19:53:34.460232
# 6   2024-10-30 19:53:34.460232
# 7   2024-10-30 19:53:34.460232
# 8   2024-10-30 19:53:34.460232
# 9   2024-10-30 19:53:34.460232
# 10  2024-10-30 19:53:34.460232
# 11  2024-10-30 19:53:34.460232
# 12  2024-10-30 19:53:34.460232
# 13  2024-10-30 19:53:34.460232
# 14  2024-10-30 19:53:34.460232
# 15  2024-10-30 19:54:35.962343
# 16  2024-10-30 19:54:35.962343
# 17  2024-10-30 19:54:35.962343
# 18  2024-10-30 19:54:35.962343
# 19  2024-10-30 19:54:35.962343
# 20  2024-10-30 19:54:35.962343
# 21  2024-10-30 19:54:35.962343
# 22  2024-10-30 19:54:35.962343
# 23  2024-10-30 19:54:35.962343
# 24  2024-10-30 19:54:35.962343
# 25  2024-10-30 19:54:35.962343
# 26  2024-10-30 19:54:35.962343
# 27  2024-10-30 19:54:35.962343
# 28  2024-10-30 19:54:35.962343
# 29  2024-10-30 19:54:35.962343

# %%
pd.set_option('display.float_format',lambda x:'%.5f' %x)

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11793
# 1    1027      Ethereum    ETH      ethereum              9468
# 2     825   Tether USDt   USDT        tether            101999
# 3    1839           BNB    BNB           bnb              2273
# 4    5426        Solana    SOL        solana               776
# 5    3408          USDC   USDC      usd-coin             22753
# 6      52           XRP    XRP           xrp              1413
# 7      74      Dogecoin   DOGE      dogecoin              1090
# 8    1958          TRON    TRX          tron              1059
# 9   11419       Toncoin    TON       toncoin               589
# 10   2010       Cardano    ADA       cardano              1310
# 11   5994     Shiba Inu   SHIB     shiba-inu               895
# 12   5805     Avalanche   AVAX     avalanche               796
# 13   1975     Chainlink   LINK     chainlink              1870
# 14   1831  Bitcoin Cash    BCH  bitcoin-cash               939
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2021-08-26T13:40:22.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2020-08-01T00:00:00.000Z
# 12  2020-07-13T00:00:00.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 7   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 8   [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 9   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...                NaN
# 10  [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 11      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 12  [defi, smart-contracts, three-arrows-capital-p...    715748719.00000
# 13  [platform, defi, oracles, smart-contracts, sub...                NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...     21000000.00000
#
#       circulating_supply          total_supply  infinite_supply  platform  \
# 0         19775359.00000        19775359.00000            False       NaN
# 1        120406284.16332       120406284.16332             True       NaN
# 2     120504138281.46748    122337925861.43820             True       NaN
# 3        145930929.81203       145930929.81203            False       NaN
# 4        470378194.51494       587536675.22982             True       NaN
# 5      34831970071.53516     34831970071.53516            False       NaN
# 6      56811862950.00000     99987068281.00000            False       NaN
# 7     146585706383.70529    146585706383.70529             True       NaN
# 8      86468085484.55890     86468105006.81549             True       NaN
# 9       2543861752.52967      5114176361.91984             True       NaN
# 10     34986894172.87286     44995214670.62046            False       NaN
# 11 589266950852374.12500 589518257425243.25000            False       NaN
# 12       407083577.53564       447086677.53564            False       NaN
# 13       626849970.45279      1000000000.00000            False       NaN
# 14        19781468.75000        19781468.75000            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                 71659659264.00000         12117858579.34287
# 9         10                  3414166606.00000         17029273528.68456
# 10        11                               NaN                       NaN
# 11        12                               NaN                       NaN
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                               NaN                       NaN
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2024-10-30T18:53:00.000Z      71909.06968     44458941060.95677
# 1       None  2024-10-30T18:53:00.000Z       2667.25558     22803268212.19041
# 2       None  2024-10-30T18:53:00.000Z          0.99957     73764318790.08818
# 3       None  2024-10-30T18:53:00.000Z        599.03982      1736983820.18401
# 4       None  2024-10-30T18:53:00.000Z        174.29191      3005015391.08078
# 5       None  2024-10-30T18:53:00.000Z          0.99982      8062646517.47520
# 6       None  2024-10-30T18:53:00.000Z          0.52297       974780894.30965
# 7       None  2024-10-30T18:53:00.000Z          0.16780      2733493615.71092
# 8       None  2024-10-30T18:53:00.000Z          0.16910       394837449.37299
# 9       None  2024-10-30T18:53:00.000Z          4.98783       215457521.96092
# 10      None  2024-10-30T18:53:00.000Z          0.35592       315504983.14061
# 11      None  2024-10-30T18:53:00.000Z          0.00002       524533148.00245
# 12      None  2024-10-30T18:53:00.000Z         26.21395       268070397.77268
# 13      None  2024-10-30T18:53:00.000Z         12.22145       316912888.50528
# 14      None  2024-10-30T18:53:00.000Z        372.64128       379119369.83293
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                     -21.82330                      0.17769
# 1                      -0.88080                     -0.16002
# 2                     -15.89430                     -0.00556
# 3                      -7.65130                      0.23364
# 4                     -26.48690                     -0.40272
# 5                     -15.25440                     -0.00942
# 6                      -7.46760                      0.02838
# 7                     -33.84160                      0.57559
# 8                       0.03890                      0.04457
# 9                      12.30790                      0.19004
# 10                      6.10850                      0.09663
# 11                    -32.24180                      0.12691
# 12                     -5.21150                      0.13482
# 13                     18.91000                      0.11272
# 14                    -13.82270                      0.54342
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -1.58696                      9.17444
# 1                        0.25070                      7.34945
# 2                       -0.02210                      0.10135
# 3                       -1.47397                      3.81107
# 4                       -4.04189                      3.00807
# 5                       -0.01264                      0.01289
# 6                       -1.32530                      1.33576
# 7                       -4.38606                     23.51009
# 8                        1.97653                      6.14213
# 9                       -2.69677                     -1.42158
# 10                       0.53382                      2.72773
# 11                      -4.22497                      6.82941
# 12                      -3.04642                     -0.05963
# 13                       4.98942                     10.18344
# 14                      -3.43345                      8.83416
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       13.56677                      22.09697
# 1                        3.13392                       6.83493
# 2                       -0.01369                      -0.06283
# 3                        4.90573                      12.38349
# 4                       12.43510                      28.54567
# 5                       -0.00321                      -0.03749
# 6                      -15.71841                      -7.67264
# 7                       42.23439                      64.84115
# 8                        8.10411                       7.15669
# 9                      -14.59821                      -7.50414
# 10                      -6.38331                       2.56390
# 11                       3.54421                      33.69627
# 12                      -6.87707                      15.73703
# 13                       2.17764                      11.02879
# 14                       8.92335                      15.50475
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       14.51799   1422027668371.54053
# 1                      -13.50788    321154333619.90845
# 2                        0.04732    120452587357.29153
# 3                        8.13966     87418437288.97342
# 4                        9.59614     81983113365.48300
# 5                       -0.01326     34825826128.92731
# 6                       -8.90718     29710826722.38911
# 7                       48.07154     24597430679.43767
# 8                       32.73486     14622006890.49057
# 9                      -25.22167     12688343189.47899
# 10                      -3.82525     12452547989.15075
# 11                      23.11997     10882098259.15068
# 12                       8.28173     10671268486.98331
# 13                       0.14058      7661014208.29353
# 14                      -4.57626      7371391891.57099
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         58.62300                 1510090463379.32007
# 1                         13.23960                  321154333619.90997
# 2                          4.96570                  122285590454.28999
# 3                          3.60380                   87418437288.97000
# 4                          3.37620                  102402888597.80000
# 5                          1.43420                   34825826128.93000
# 6                          1.22350                   52296871075.21000
# 7                          1.01400                   24597430679.44000
# 8                          0.60220                   14622010191.76000
# 9                          0.52250                   25508628661.53000
# 10                         0.51280                   16016416225.54000
# 11                         0.44920                   10886739182.62000
# 12                         0.43990                   18762601026.31000
# 13                         0.31580                   12221447825.48000
# 14                         0.30390                    7825466939.76000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-10-30T18:53:00.000Z          NaN           NaN
# 1           None  2024-10-30T18:53:00.000Z          NaN           NaN
# 2           None  2024-10-30T18:53:00.000Z   1027.00000      Ethereum
# 3           None  2024-10-30T18:53:00.000Z          NaN           NaN
# 4           None  2024-10-30T18:53:00.000Z          NaN           NaN
# 5           None  2024-10-30T18:53:00.000Z   1027.00000      Ethereum
# 6           None  2024-10-30T18:53:00.000Z          NaN           NaN
# 7           None  2024-10-30T18:53:00.000Z          NaN           NaN
# 8           None  2024-10-30T18:53:00.000Z          NaN           NaN
# 9           None  2024-10-30T18:53:00.000Z          NaN           NaN
# 10          None  2024-10-30T18:53:00.000Z          NaN           NaN
# 11          None  2024-10-30T18:53:00.000Z   1027.00000      Ethereum
# 12          None  2024-10-30T18:53:00.000Z          NaN           NaN
# 13          None  2024-10-30T18:53:00.000Z   1027.00000      Ethereum
# 14          None  2024-10-30T18:53:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 12             NaN           NaN                                         NaN
# 13             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14             NaN           NaN                                         NaN
#
#                    time_stamp
# 0  2024-10-30 19:54:35.962343
# 1  2024-10-30 19:54:35.962343
# 2  2024-10-30 19:54:35.962343
# 3  2024-10-30 19:54:35.962343
# 4  2024-10-30 19:54:35.962343
# 5  2024-10-30 19:54:35.962343
# 6  2024-10-30 19:54:35.962343
# 7  2024-10-30 19:54:35.962343
# 8  2024-10-30 19:54:35.962343
# 9  2024-10-30 19:54:35.962343
# 10 2024-10-30 19:54:35.962343
# 11 2024-10-30 19:54:35.962343
# 12 2024-10-30 19:54:35.962343
# 13 2024-10-30 19:54:35.962343
# 14 2024-10-30 19:54:35.962343

# %% [markdown]
# No kernel connected
